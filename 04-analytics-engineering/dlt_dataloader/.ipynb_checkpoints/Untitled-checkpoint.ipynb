# %%
# !pip install dlt[bigquery]
# Out:
# Requirement already satisfied: dlt[bigquery] in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (1.5.0)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (6.0.2)
# Requirement already satisfied: click>=7.1 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (8.1.8)
# Requirement already satisfied: fsspec>=2022.4.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (2025.2.0)
# Requirement already satisfied: gitpython>=3.1.29 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (3.1.44)
# Requirement already satisfied: giturlparse>=0.10.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (0.12.0)
# Requirement already satisfied: hexbytes>=0.2.2 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (1.3.0)
# Requirement already satisfied: humanize>=4.4.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (4.12.1)
# Requirement already satisfied: jsonpath-ng>=1.5.3 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (1.6.1)
# Requirement already satisfied: makefun>=1.15.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (1.15.6)
# Requirement already satisfied: orjson!=3.10.1,!=3.9.11,!=3.9.12,!=3.9.13,!=3.9.14,<4,>=3.6.7 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (3.10.15)
# Requirement already satisfied: packaging>=21.1 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (24.2)
# Requirement already satisfied: pathvalidate>=2.5.2 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (3.2.3)
# Requirement already satisfied: pendulum>=2.1.2 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (3.0.0)
# Requirement already satisfied: pluggy>=1.3.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (1.5.0)
# Requirement already satisfied: pytz>=2022.6 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (2025.1)
# Requirement already satisfied: requests>=2.26.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (2.32.3)
# Requirement already satisfied: requirements-parser>=0.5.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (0.11.0)
# Requirement already satisfied: semver>=3.0.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (3.0.4)
# Requirement already satisfied: setuptools>=65.6.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (75.8.2)
# Requirement already satisfied: simplejson>=3.17.5 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (3.20.1)
# Requirement already satisfied: tenacity>=8.0.2 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (9.0.0)
# Requirement already satisfied: tomlkit>=0.11.3 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (0.13.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (4.12.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (2025.1)
# Requirement already satisfied: win-precise-time>=1.4.2 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (1.4.2)
# Requirement already satisfied: db-dtypes>=1.2.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (1.4.1)
# Requirement already satisfied: gcsfs>=2022.4.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (2025.2.0)
# Requirement already satisfied: google-cloud-bigquery>=2.26.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (3.30.0)
# Requirement already satisfied: grpcio>=1.50.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (1.71.0rc2)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from dlt[bigquery]) (19.0.1)
# Requirement already satisfied: colorama in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from click>=7.1->dlt[bigquery]) (0.4.6)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from db-dtypes>=1.2.0->dlt[bigquery]) (2.2.2)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from db-dtypes>=1.2.0->dlt[bigquery]) (2.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from gcsfs>=2022.4.0->dlt[bigquery]) (3.11.13)
# Requirement already satisfied: decorator>4.1.2 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from gcsfs>=2022.4.0->dlt[bigquery]) (5.2.1)
# Requirement already satisfied: google-auth>=1.2 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from gcsfs>=2022.4.0->dlt[bigquery]) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from gcsfs>=2022.4.0->dlt[bigquery]) (1.2.1)
# Requirement already satisfied: google-cloud-storage in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from gcsfs>=2022.4.0->dlt[bigquery]) (3.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from gitpython>=3.1.29->dlt[bigquery]) (4.0.12)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.11.1 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=2.26.0->dlt[bigquery]) (2.24.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from google-cloud-bigquery>=2.26.0->dlt[bigquery]) (2.4.2)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from google-cloud-bigquery>=2.26.0->dlt[bigquery]) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.3 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from google-cloud-bigquery>=2.26.0->dlt[bigquery]) (2.9.0.post0)
# Requirement already satisfied: ply in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from jsonpath-ng>=1.5.3->dlt[bigquery]) (3.11)
# Requirement already satisfied: time-machine>=2.6.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from pendulum>=2.1.2->dlt[bigquery]) (2.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from requests>=2.26.0->dlt[bigquery]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from requests>=2.26.0->dlt[bigquery]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from requests>=2.26.0->dlt[bigquery]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from requests>=2.26.0->dlt[bigquery]) (2025.1.31)
# Requirement already satisfied: types-setuptools>=69.1.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from requirements-parser>=0.5.0->dlt[bigquery]) (75.8.0.20250225)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery]) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery]) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery]) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery]) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery]) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.4.0->dlt[bigquery]) (1.18.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.29->dlt[bigquery]) (5.0.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from google-api-core<3.0.0dev,>=2.11.1->google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=2.26.0->dlt[bigquery]) (1.68.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from google-api-core<3.0.0dev,>=2.11.1->google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=2.26.0->dlt[bigquery]) (5.28.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from google-api-core<3.0.0dev,>=2.11.1->google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=2.26.0->dlt[bigquery]) (1.26.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=2.26.0->dlt[bigquery]) (1.71.0rc2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from google-auth>=1.2->gcsfs>=2022.4.0->dlt[bigquery]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from google-auth>=1.2->gcsfs>=2022.4.0->dlt[bigquery]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from google-auth>=1.2->gcsfs>=2022.4.0->dlt[bigquery]) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from google-resumable-media<3.0dev,>=2.0.0->google-cloud-bigquery>=2.26.0->dlt[bigquery]) (1.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from python-dateutil<3.0dev,>=2.7.3->google-cloud-bigquery>=2.26.0->dlt[bigquery]) (1.17.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from google-auth-oauthlib->gcsfs>=2022.4.0->dlt[bigquery]) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs>=2022.4.0->dlt[bigquery]) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\satiy\anaconda3\envs\dlt_env\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs>=2022.4.0->dlt[bigquery]) (3.2.2)

# %%
import itertools, os
from tqdm import tqdm_notebook
year = ['2019','2020']
months = list(map(lambda x: '0'+str(x) if x<10 else str(x), list(range(1,13))))
year_months = set(itertools.product(months, year))

# %%
URLS = []
for month, year in year_months:
    YELLOW_URL = f"https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_{year}-{month}.csv.gz"
    GREEN_URL = f"https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_{year}-{month}.csv.gz"
    URLS.extend([YELLOW_URL, GREEN_URL])

# %%
len(URLS)
# Out:
# 48

# %%
os.makedirs('data/yellow')
os.makedirs('data/green')

# %%
for URL in tqdm_notebook(URLS):
    dirpath = ['data']
    dirpath.extend(URL.split('/')[-2:])
    dirpath = '/'.join(dirpath)
    os.system(f"wget {URL} -O {dirpath}")

# %%
import dlt
from dlt.sources.filesystem import filesystem, read_csv

files = filesystem(bucket_url="data//green", file_glob="*.csv.gz")
reader = (files | read_csv()).with_name("green_tripdata")
pipeline = dlt.pipeline(pipeline_name="green_taxi_datapipe", dataset_name="trips_homework4", destination="bigquery")

info = pipeline.run(reader)
print(info)
# Out:
# C:\Users\satiy\anaconda3\envs\dlt_env\lib\site-packages\google\cloud\bigquery\client.py:595: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   warnings.warn(
